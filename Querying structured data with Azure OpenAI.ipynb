# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Welcome to your new notebook
# Type here in the cell editor to add code!

# Imagine you have a lot of structured data and you want to extract relevant information from them. 
# You might also want to generate some simulations, asking for specific KPIs but also generating reports about the main relevances caught in data.
# In fact, with so much structured data, you might also be in a condition where you are not sure what the relevant information is.
# The classical approach in this case would be that of doing some descriptive analytics using a statistical approach. 
# It could be with Python, R, or SQL queries.
# But what if you “ask” your datasets questions in natural language? 
# And what if you ask not only to compute numerical output but also generate analysis about trends, KPIs, and best next actions?
# In this article, I’m going to share some experiments It turned out that Azure OpenAI models work pretty well on that.

# %% [markdown]
# Let’s start by creating a pandas data frame of an imaginary Sales table:

# %%
import pandas as pd
import numpy as np

# Create dataframe with 1000 rows
df = pd.DataFrame({
    'Sales Order': np.arange(1, 1001),
    'Order Date': np.random.choice(pd.date_range(start='2020-01-01', end='2022-01-01'), 1000),
    'Customer': [f'Customer {i}' for i in np.random.choice(10, 1000)],
    'Product': [f"Product {chr(65+i%26)}" for i in np.random.choice(10,1000)],
    'Quantity': np.random.randint(1, 100, 1000),
    'Price': np.random.randint(10, 1000, 1000),
    'Revenue': np.random.randint(1000, 100000, 1000)
})

# Preview the dataframe
df.head()
# Out:
#    Sales Order Order Date    Customer    Product  Quantity  Price  Revenue
# 0            1 2021-11-23  Customer 1  Product D        75    984    79134
# 1            2 2020-10-07  Customer 0  Product F        66     45    16336
# 2            3 2020-01-11  Customer 8  Product C        11    235    43371
# 3            4 2021-03-04  Customer 8  Product F        86    682    14043
# 4            5 2021-03-13  Customer 7  Product B        41    513    71910

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\pasca\anaconda3\lib\site-packages (0.28.0)
# Requirement already satisfied: tqdm in c:\users\pasca\anaconda3\lib\site-packages (from openai) (4.64.0)
# Requirement already satisfied: aiohttp in c:\users\pasca\anaconda3\lib\site-packages (from openai) (3.8.1)
# Requirement already satisfied: requests>=2.20 in c:\users\pasca\anaconda3\lib\site-packages (from openai) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pasca\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pasca\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pasca\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pasca\anaconda3\lib\site-packages (from requests>=2.20->openai) (2021.10.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pasca\anaconda3\lib\site-packages (from aiohttp->openai) (5.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pasca\anaconda3\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pasca\anaconda3\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pasca\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\pasca\anaconda3\lib\site-packages (from aiohttp->openai) (1.6.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\pasca\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\pasca\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->openai) (4.9.0)
# Requirement already satisfied: colorama in c:\users\pasca\anaconda3\lib\site-packages (from tqdm->openai) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install openai
import openai



openai.api_type = "azure"
openai.api_base = "https://aiinsight-aoai.openai.azure.com/"
openai.api_version = "2023-09-15-preview"
openai.api_key = "99058afc6c1d44d2aa89662c260a1d99"

# %%
pre_text = df.head(10).to_json(orient="records")


query = input("Enter your query in natural language: ")
response = openai.Completion.create(
  engine="TSL",
  prompt=pre_text + "\n" + query,
  temperature=0.7,
  max_tokens=2048,
  top_p=0,
  frequency_penalty=0,
  presence_penalty=0,
  best_of=1,
  stop=None)

response = response.choices[0].text
print("OpenAI response: ", response)
# Out:
# OpenAI response:
#
# Product F
